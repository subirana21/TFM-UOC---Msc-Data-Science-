# %% [markdown]
# # TFM UOC

# %% [markdown]
# # Fase 1 - Analisis de datos

# %%
import pandas as pd # Data handling and managing
import numpy as np  # Handiling linear Algera
import seaborn as sn
import datetime 
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns

import pmdarima as pm

# %matplotlib inline

# %%
def check_df(dataframe):
    print("##################### Shape #####################")
    print(dataframe.shape)
    print("##################### Types #####################")
    print(dataframe.dtypes)
    print("##################### Head #####################")
    print(dataframe.head(3))
    print("##################### Tail #####################")
    print(dataframe.tail(3))
    print("##################### NA #####################")
    print(dataframe.isnull().sum())
    print("##################### Quantiles #####################")
    print(dataframe.quantile([0, 0.05, 0.50, 0.95, 0.99, 1]).T)

# %%
dataset=pd.read_excel(r'C:\Users\subir\OneDrive\Escritorio\PC ANTIC\UOC\TFM\Dataset_Completo_Fase2.xlsx')
dataset.drop(dataset.columns[0], axis=1, inplace=True)
print(dataset)
# Out:
#             Fecha  Producto  udsVenta  flag    Precio  Festivo  Fin de semana
# 0      2015-06-29         1      3629     0  4.394742        0              0
# 1      2015-06-30         1      4666     0  4.394742        0              0
# 2      2015-07-01         1     16070     0  4.394742        0              0
# 3      2015-07-02         1      4666     0  4.394742        0              0
# 4      2015-07-03         1      8813     0  4.394742        0              0
# ...           ...       ...       ...   ...       ...      ...            ...
# 140541 2021-03-19        99       540     0  4.394742        0              0
# 140542 2021-03-20        99         0     0  4.394742        0              1
# 140543 2021-03-21        99         0     0  4.394742        0              1
# 140544 2021-03-22        99         0     0  4.394742        0              0
# 140545 2021-03-23        99       162     0  4.394742        0              0
#
# [140546 rows x 7 columns]

# %%
#var['Fecha']=pd.to_datetime(dataset['Fecha'])
dataset['Fecha_2']=pd.to_datetime(dataset['Fecha'])

dataset['Año']=dataset['Fecha_2'].dt.year
dataset['Mes']=dataset['Fecha_2'].dt.month
dataset['Weekday']=dataset['Fecha_2'].dt.weekday

# %%
dataset.head()
# Out:
#        Fecha  Producto  udsVenta  udsStock  flag  Precio  Festivo  \
# 0 2019-06-05         1      2074     10184     0  4.1931        0
# 1 2019-06-06         1     12787      4918     1  3.2613        0
# 2 2019-06-07         1      3110      4918     0  4.1931        0
# 3 2019-06-08         1         0      4918     0  4.1931        0
# 4 2019-06-09         1         0      4918     0  4.1931        0
#
#    Fin de semana    Fecha_2   Año  Mes  Weekday
# 0              0 2019-06-05  2019    6        2
# 1              0 2019-06-06  2019    6        3
# 2              0 2019-06-07  2019    6        4
# 3              1 2019-06-08  2019    6        5
# 4              1 2019-06-09  2019    6        6

# %%
sns.lineplot(x="Fecha", y="udsVenta",legend = 'full' , data=dataset)
# Out:
# <AxesSubplot:xlabel='Fecha', ylabel='udsVenta'>

# %%
sns.lineplot(x="Año", y="udsVenta",legend = 'full' , data=dataset)
# Out:
# <AxesSubplot:xlabel='Año', ylabel='udsVenta'>

# %%
sns.lineplot(x="Mes", y="udsVenta",legend = 'full' , data=dataset)
# Out:
# <AxesSubplot:xlabel='Mes', ylabel='udsVenta'>

# %%
sns.lineplot(x="Weekday", y="udsVenta",legend = 'full' , data=dataset)
# Out:
# <AxesSubplot:xlabel='Weekday', ylabel='udsVenta'>

# %%
#Los outliers no nos permiten ver claramente la distribucion de los datos
sns.boxplot(x="Weekday", y="udsVenta", data=dataset)
# Out:
# <AxesSubplot:xlabel='Weekday', ylabel='udsVenta'>

# %% [markdown]
# Aqui vemos que hay muchos outliers a tratar

# %% [markdown]
# # Para tratar outliers utilizamos IQR score

# %% [markdown]
# Tener en cuenta que en el caso de arima es iomportante tratar los outliers ya que pueden tener un efecto negativo sobretodo si tratamos con datos referentes al pasado. Ver https://www.researchgate.net/publication/4960827_The_effect_of_additive_outliers_on_the_forecasts_from_ARIMA_models

# %% [markdown]
# ### Outliers Ventas

# %%
Q1_ventas=dataset['udsVenta'].quantile(0.25)
Q3_ventas=dataset['udsVenta'].quantile(0.75)
IQR_ventas=Q3_ventas-Q1_ventas

Limit_lower=Q1_ventas-(1.5*IQR_ventas)
Limit_upper=Q3_ventas+(1.5*IQR_ventas)

# %%
#Mostramos outliers
dataset[((dataset["udsVenta"] < Limit_lower) |(dataset["udsVenta"] > Limit_upper))]
# Out:
#            Fecha  Producto  udsVenta  udsStock  flag   Precio  Festivo  \
# 0     2019-06-05         1      2074     10184     0  4.19310        0
# 1     2019-06-06         1     12787      4918     1  3.26130        0
# 2     2019-06-07         1      3110      4918     0  4.19310        0
# 5     2019-06-10         1      5875      4918     0  4.19310        0
# 8     2019-06-13         1      4147      4036     0  4.19310        0
# ...          ...       ...       ...       ...   ...      ...      ...
# 34266 2020-08-12        80      2052       339     0  4.35323        0
# 40970 2020-04-09        99      2808       346     0  4.35323        1
# 41091 2020-08-08        99      3056       346     0  4.35323        0
# 41094 2020-08-11        99      3262       346     0  4.35323        0
# 41098 2020-08-15        99      3785       346     0  4.35323        1
#
#        Fin de semana    Fecha_2   Año  Mes  Weekday
# 0                  0 2019-06-05  2019    6        2
# 1                  0 2019-06-06  2019    6        3
# 2                  0 2019-06-07  2019    6        4
# 5                  0 2019-06-10  2019    6        0
# 8                  0 2019-06-13  2019    6        3
# ...              ...        ...   ...  ...      ...
# 34266              0 2020-08-12  2020    8        2
# 40970              0 2020-04-09  2020    4        3
# 41091              1 2020-08-08  2020    8        5
# 41094              0 2020-08-11  2020    8        1
# 41098              1 2020-08-15  2020    8        5
#
# [3253 rows x 12 columns]

# %%
#Eliminamos outliers
dataset[~((dataset["udsVenta"] < Limit_lower) |(dataset["udsVenta"] > Limit_upper))]
# Out:
#            Fecha  Producto  udsVenta  udsStock  flag   Precio  Festivo  \
# 3     2019-06-08         1         0      4918     0  4.19310        0
# 4     2019-06-09         1         0      4918     0  4.19310        0
# 6     2019-06-11         1      1037      1627     0  4.19310        0
# 7     2019-06-12         1      1382      3751     0  4.19310        0
# 10    2019-06-15         1       691      7484     0  4.19310        0
# ...          ...       ...       ...       ...   ...      ...      ...
# 41300 2021-03-05        99         0       346     0  4.35323        0
# 41301 2021-03-06        99         0       346     0  4.35323        0
# 41302 2021-03-07        99         0       346     0  4.35323        0
# 41303 2021-03-08        99         0       346     0  4.35323        0
# 41304 2021-03-09        99         0       540     0  4.35323        0
#
#        Fin de semana    Fecha_2   Año  Mes  Weekday
# 3                  1 2019-06-08  2019    6        5
# 4                  1 2019-06-09  2019    6        6
# 6                  0 2019-06-11  2019    6        1
# 7                  0 2019-06-12  2019    6        2
# 10                 1 2019-06-15  2019    6        5
# ...              ...        ...   ...  ...      ...
# 41300              0 2021-03-05  2021    3        4
# 41301              1 2021-03-06  2021    3        5
# 41302              1 2021-03-07  2021    3        6
# 41303              0 2021-03-08  2021    3        0
# 41304              0 2021-03-09  2021    3        1
#
# [38052 rows x 12 columns]

# %%
dataset=dataset[~((dataset["udsVenta"] < Limit_lower) |(dataset["udsVenta"] > Limit_upper))]

# %%
#Ahora ya se muestra mejor
sns.boxplot(x="Weekday", y="udsVenta", data=dataset)
# Out:
# <AxesSubplot:xlabel='Weekday', ylabel='udsVenta'>

# %% [markdown]
# ### Outliers Precio

# %%
Q1_precios=dataset['Precio'].quantile(0.25)
Q3_precios=dataset['Precio'].quantile(0.75)
IQR_precios=Q3_precios-Q1_precios

Limit_lower_precios=Q1_precios-(1.5*IQR_precios)
Limit_upper_precios=Q3_precios+(1.5*IQR_precios)

# %%
#Mostramos outliers
dataset[((dataset["Precio"] < Limit_lower_precios) |(dataset["Precio"] > Limit_upper_precios))]
# Out:
#            Fecha  Producto  udsVenta  udsStock  flag  Precio  Festivo  \
# 7936  2020-01-30        17      1704       641     0  6.2127        0
# 7938  2020-02-01        17      1026       360     0  6.2127        0
# 7939  2020-02-02        17         0      1918     0  6.2127        0
# 7940  2020-02-03        17      1579       380     0  6.2127        0
# 7941  2020-02-04        17      1204      1918     0  6.2127        0
# ...          ...       ...       ...       ...   ...     ...      ...
# 40536 2020-06-22        98       344       259     1  2.2610        0
# 40537 2020-06-23        98       194       269     1  2.2610        0
# 40538 2020-06-24        98       149       297     1  2.2610        0
# 40539 2020-06-25        98       192       307     1  2.2610        0
# 40540 2020-06-26        98       297       286     1  2.2610        0
#
#        Fin de semana    Fecha_2   Año  Mes  Weekday
# 7936               0 2020-01-30  2020    1        3
# 7938               1 2020-02-01  2020    2        5
# 7939               1 2020-02-02  2020    2        6
# 7940               0 2020-02-03  2020    2        0
# 7941               0 2020-02-04  2020    2        1
# ...              ...        ...   ...  ...      ...
# 40536              0 2020-06-22  2020    6        0
# 40537              0 2020-06-23  2020    6        1
# 40538              0 2020-06-24  2020    6        2
# 40539              0 2020-06-25  2020    6        3
# 40540              0 2020-06-26  2020    6        4
#
# [2267 rows x 12 columns]

# %%
#Eliminamos outliers
dataset[~((dataset["Precio"] < Limit_lower_precios) |(dataset["Precio"] > Limit_upper_precios))]
# Out:
#            Fecha  Producto  udsVenta  udsStock  flag   Precio  Festivo  \
# 3     2019-06-08         1         0      4918     0  4.19310        0
# 4     2019-06-09         1         0      4918     0  4.19310        0
# 6     2019-06-11         1      1037      1627     0  4.19310        0
# 7     2019-06-12         1      1382      3751     0  4.19310        0
# 10    2019-06-15         1       691      7484     0  4.19310        0
# ...          ...       ...       ...       ...   ...      ...      ...
# 41300 2021-03-05        99         0       346     0  4.35323        0
# 41301 2021-03-06        99         0       346     0  4.35323        0
# 41302 2021-03-07        99         0       346     0  4.35323        0
# 41303 2021-03-08        99         0       346     0  4.35323        0
# 41304 2021-03-09        99         0       540     0  4.35323        0
#
#        Fin de semana    Fecha_2   Año  Mes  Weekday
# 3                  1 2019-06-08  2019    6        5
# 4                  1 2019-06-09  2019    6        6
# 6                  0 2019-06-11  2019    6        1
# 7                  0 2019-06-12  2019    6        2
# 10                 1 2019-06-15  2019    6        5
# ...              ...        ...   ...  ...      ...
# 41300              0 2021-03-05  2021    3        4
# 41301              1 2021-03-06  2021    3        5
# 41302              1 2021-03-07  2021    3        6
# 41303              0 2021-03-08  2021    3        0
# 41304              0 2021-03-09  2021    3        1
#
# [35785 rows x 12 columns]

# %%
dataset=dataset[~((dataset["Precio"] < Limit_lower_precios) |(dataset["Precio"] > Limit_upper_precios))]

# %%
#Ahora ya se muestra mejor
sns.boxplot(x="Weekday", y="Precio", data=dataset)
# Out:
# <AxesSubplot:xlabel='Weekday', ylabel='Precio'>

# %% [markdown]
# ### Outliers Stock

# %%
Q1_stock=dataset['udsStock'].quantile(0.25)
Q3_stock=dataset['udsStock'].quantile(0.75)
IQR_stock=Q3_stock-Q1_stock

Limit_lower_stock=Q1_stock-(1.5*IQR_stock)
Limit_upper_stock=Q3_stock+(1.5*IQR_stock)

# %%
#Mostramos outliers
dataset[((dataset["udsStock"] < Limit_lower_stock) |(dataset["udsStock"] > Limit_upper_stock))]
# Out:
#            Fecha  Producto  udsVenta  udsStock  flag   Precio  Festivo  \
# 3     2019-06-08         1         0      4918     0  4.19310        0
# 4     2019-06-09         1         0      4918     0  4.19310        0
# 7     2019-06-12         1      1382      3751     0  4.19310        0
# 10    2019-06-15         1       691      7484     0  4.19310        0
# 13    2019-06-18         1       691      2815     0  4.19310        0
# ...          ...       ...       ...       ...   ...      ...      ...
# 34491 2021-02-26        81         0      2608     0  4.35323        0
# 34492 2021-02-27        81         0      2608     0  4.35323        0
# 34493 2021-02-28        81         0      2608     0  4.35323        0
# 34494 2021-03-01        81         0      2608     0  4.35323        0
# 34495 2021-03-02        81         0      2608     0  4.35323        0
#
#        Fin de semana    Fecha_2   Año  Mes  Weekday
# 3                  1 2019-06-08  2019    6        5
# 4                  1 2019-06-09  2019    6        6
# 7                  0 2019-06-12  2019    6        2
# 10                 1 2019-06-15  2019    6        5
# 13                 0 2019-06-18  2019    6        1
# ...              ...        ...   ...  ...      ...
# 34491              0 2021-02-26  2021    2        4
# 34492              1 2021-02-27  2021    2        5
# 34493              1 2021-02-28  2021    2        6
# 34494              0 2021-03-01  2021    3        0
# 34495              0 2021-03-02  2021    3        1
#
# [2291 rows x 12 columns]

# %%
#Eliminamos outliers
dataset[~((dataset["udsStock"] < Limit_lower_stock) |(dataset["udsStock"] > Limit_upper_stock))]
# Out:
#            Fecha  Producto  udsVenta  udsStock  flag   Precio  Festivo  \
# 6     2019-06-11         1      1037      1627     0  4.19310        0
# 11    2019-06-16         1         0       227     0  4.19310        0
# 14    2019-06-19         1      1382      1433     0  4.19310        0
# 46    2019-07-21         1         0      1141     0  4.19310        0
# 53    2019-07-28         1         0       961     0  4.19310        0
# ...          ...       ...       ...       ...   ...      ...      ...
# 41300 2021-03-05        99         0       346     0  4.35323        0
# 41301 2021-03-06        99         0       346     0  4.35323        0
# 41302 2021-03-07        99         0       346     0  4.35323        0
# 41303 2021-03-08        99         0       346     0  4.35323        0
# 41304 2021-03-09        99         0       540     0  4.35323        0
#
#        Fin de semana    Fecha_2   Año  Mes  Weekday
# 6                  0 2019-06-11  2019    6        1
# 11                 1 2019-06-16  2019    6        6
# 14                 0 2019-06-19  2019    6        2
# 46                 1 2019-07-21  2019    7        6
# 53                 1 2019-07-28  2019    7        6
# ...              ...        ...   ...  ...      ...
# 41300              0 2021-03-05  2021    3        4
# 41301              1 2021-03-06  2021    3        5
# 41302              1 2021-03-07  2021    3        6
# 41303              0 2021-03-08  2021    3        0
# 41304              0 2021-03-09  2021    3        1
#
# [33494 rows x 12 columns]

# %%
dataset=dataset[~((dataset["udsStock"] < Limit_lower_stock) |(dataset["udsStock"] > Limit_upper_stock))]

# %%
#Ahora ya se muestra mejor
sns.boxplot(x="Weekday", y="udsStock", data=dataset)
# Out:
# <AxesSubplot:xlabel='Weekday', ylabel='udsStock'>

# %%
dataset
# Out:
#            Fecha  Producto  udsVenta  udsStock  flag   Precio  Festivo  \
# 6     2019-06-11         1      1037      1627     0  4.19310        0
# 11    2019-06-16         1         0       227     0  4.19310        0
# 14    2019-06-19         1      1382      1433     0  4.19310        0
# 46    2019-07-21         1         0      1141     0  4.19310        0
# 53    2019-07-28         1         0       961     0  4.19310        0
# ...          ...       ...       ...       ...   ...      ...      ...
# 41300 2021-03-05        99         0       346     0  4.35323        0
# 41301 2021-03-06        99         0       346     0  4.35323        0
# 41302 2021-03-07        99         0       346     0  4.35323        0
# 41303 2021-03-08        99         0       346     0  4.35323        0
# 41304 2021-03-09        99         0       540     0  4.35323        0
#
#        Fin de semana    Fecha_2   Año  Mes  Weekday
# 6                  0 2019-06-11  2019    6        1
# 11                 1 2019-06-16  2019    6        6
# 14                 0 2019-06-19  2019    6        2
# 46                 1 2019-07-21  2019    7        6
# 53                 1 2019-07-28  2019    7        6
# ...              ...        ...   ...  ...      ...
# 41300              0 2021-03-05  2021    3        4
# 41301              1 2021-03-06  2021    3        5
# 41302              1 2021-03-07  2021    3        6
# 41303              0 2021-03-08  2021    3        0
# 41304              0 2021-03-09  2021    3        1
#
# [33494 rows x 12 columns]

# %% [markdown]
# ## Comprovamos la estacionalidad

# %% [markdown]
# Utilizamos el metodo de Dickey-Fullers test

# %% [markdown]
# Necesario para poder aplicar ARIMA

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries, window = 12, cutoff = 0.01):

    #Determing rolling statistics
    rolmean = timeseries.rolling(window).mean()
    rolstd = timeseries.rolling(window).std()

    #Plot rolling statistics:
    fig = plt.figure(figsize=(12, 8))
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show()
    
    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC', maxlag = 20 )
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    pvalue = dftest[1]
    if pvalue < cutoff:
        print('p-value = %.4f. The series is likely stationary.' % pvalue)
    else:
        print('p-value = %.4f. The series is likely non-stationary.' % pvalue)
    
    print(dfoutput)

# %%
test_stationarity(dataset['udsVenta'])
# Out:
# Results of Dickey-Fuller Test:
# p-value = 0.0000. The series is likely stationary.
# Test Statistic                   -19.240312
# p-value                            0.000000
# #Lags Used                        20.000000
# Number of Observations Used    33473.000000
# Critical Value (1%)               -3.430545
# Critical Value (5%)               -2.861626
# Critical Value (10%)              -2.566816
# dtype: float64

# %%
#ADF-test(Original-time-series)
res = sm.tsa.adfuller(dataset['udsVenta'].dropna(),regression='ct')
print('p-value:{}'.format(res[1]))
# Out:
# p-value:5.43650851109978e-20

# %%
#ADF-test(differenced-time-series)
res = sm.tsa.adfuller(dataset['udsVenta'].diff().dropna(),regression='c')
print('p-value:{}'.format(res[1]))
# Out:
# p-value:0.0

# %%
from statsmodels.tsa.stattools import adfuller
series = dataset['udsVenta']
X = series.values
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -9.425835
# p-value: 0.000000

# %% [markdown]
# Despues de probarlo de varias manera en todas obtenemos un p-value <= 0.05, por este motivo rechazamos la hipotesis nula en que los datos son estacionarios.

# %%
dataset
# Out:
#            Fecha  Producto  udsVenta  udsStock  flag   Precio  Festivo  \
# 6     2019-06-11         1      1037      1627     0  4.19310        0
# 11    2019-06-16         1         0       227     0  4.19310        0
# 14    2019-06-19         1      1382      1433     0  4.19310        0
# 46    2019-07-21         1         0      1141     0  4.19310        0
# 53    2019-07-28         1         0       961     0  4.19310        0
# ...          ...       ...       ...       ...   ...      ...      ...
# 41300 2021-03-05        99         0       346     0  4.35323        0
# 41301 2021-03-06        99         0       346     0  4.35323        0
# 41302 2021-03-07        99         0       346     0  4.35323        0
# 41303 2021-03-08        99         0       346     0  4.35323        0
# 41304 2021-03-09        99         0       540     0  4.35323        0
#
#        Fin de semana    Fecha_2   Año  Mes  Weekday
# 6                  0 2019-06-11  2019    6        1
# 11                 1 2019-06-16  2019    6        6
# 14                 0 2019-06-19  2019    6        2
# 46                 1 2019-07-21  2019    7        6
# 53                 1 2019-07-28  2019    7        6
# ...              ...        ...   ...  ...      ...
# 41300              0 2021-03-05  2021    3        4
# 41301              1 2021-03-06  2021    3        5
# 41302              1 2021-03-07  2021    3        6
# 41303              0 2021-03-08  2021    3        0
# 41304              0 2021-03-09  2021    3        1
#
# [33494 rows x 12 columns]

# %%
dataset=dataset.drop(columns='Fecha_2')
dataset=dataset.set_index('Fecha')

# %%
dataset
# Out:
#            Fecha  Producto  udsVenta  udsStock  flag   Precio  Festivo  \
# 6     2019-06-11         1      1037      1627     0  4.19310        0
# 11    2019-06-16         1         0       227     0  4.19310        0
# 14    2019-06-19         1      1382      1433     0  4.19310        0
# 46    2019-07-21         1         0      1141     0  4.19310        0
# 53    2019-07-28         1         0       961     0  4.19310        0
# ...          ...       ...       ...       ...   ...      ...      ...
# 41300 2021-03-05        99         0       346     0  4.35323        0
# 41301 2021-03-06        99         0       346     0  4.35323        0
# 41302 2021-03-07        99         0       346     0  4.35323        0
# 41303 2021-03-08        99         0       346     0  4.35323        0
# 41304 2021-03-09        99         0       540     0  4.35323        0
#
#        Fin de semana    Fecha_2   Año  Mes  Weekday
# 6                  0 2019-06-11  2019    6        1
# 11                 1 2019-06-16  2019    6        6
# 14                 0 2019-06-19  2019    6        2
# 46                 1 2019-07-21  2019    7        6
# 53                 1 2019-07-28  2019    7        6
# ...              ...        ...   ...  ...      ...
# 41300              0 2021-03-05  2021    3        4
# 41301              1 2021-03-06  2021    3        5
# 41302              1 2021-03-07  2021    3        6
# 41303              0 2021-03-08  2021    3        0
# 41304              0 2021-03-09  2021    3        1
#
# [33494 rows x 12 columns]

# %% [markdown]
# Debido a que hemos visto que los datos eran estacionarios, dentro de los modelos dentro de ARIMA, seleccionaremos SARIMA y SARIMAX que son lo indicados en caso que los datos presenten estacionalidad. Para seleccionar los mejores parametros utilizaremos auto_arima, pero si leemos la documentación de esta función hemos de tener en cuenta que puede mostrar resultados infinitos y marcarlos como los mejores. Esta afirmación no es correcta aunque el plot nos lo muestre así, hemos de seleccionar el AIC más bajo posible.

# %%
Utilizamos auto_arima con SARIMA

# %%
import pmdarima as pm

model = pm.auto_arima(dataset['udsVenta'], start_p=1, start_q=1,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=3,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=True,   # Seasonality
                      start_P=0, 
                      D=1, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)

print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,1,1)[3] intercept   : AIC=inf, Time=30.05 sec
#  ARIMA(0,0,0)(0,1,0)[3] intercept   : AIC=513409.976, Time=0.53 sec
#  ARIMA(1,0,0)(1,1,0)[3] intercept   : AIC=501241.471, Time=10.44 sec
#  ARIMA(0,0,1)(0,1,1)[3] intercept   : AIC=491508.677, Time=27.05 sec
#  ARIMA(0,0,0)(0,1,0)[3]             : AIC=513407.976, Time=0.29 sec
#  ARIMA(0,0,1)(0,1,0)[3] intercept   : AIC=512235.736, Time=5.83 sec
#  ARIMA(0,0,1)(1,1,1)[3] intercept   : AIC=491466.878, Time=26.49 sec
#  ARIMA(0,0,1)(1,1,0)[3] intercept   : AIC=501202.698, Time=8.48 sec
#  ARIMA(0,0,1)(2,1,1)[3] intercept   : AIC=inf, Time=26.50 sec
#  ARIMA(0,0,1)(1,1,2)[3] intercept   : AIC=inf, Time=46.74 sec
#  ARIMA(0,0,1)(0,1,2)[3] intercept   : AIC=491473.618, Time=33.25 sec
#  ARIMA(0,0,1)(2,1,0)[3] intercept   : AIC=498988.365, Time=12.91 sec
#  ARIMA(0,0,1)(2,1,2)[3] intercept   : AIC=inf, Time=56.01 sec
#  ARIMA(0,0,0)(1,1,1)[3] intercept   : AIC=493137.281, Time=28.51 sec
#  ARIMA(1,0,1)(1,1,1)[3] intercept   : AIC=inf, Time=47.57 sec
#  ARIMA(0,0,2)(1,1,1)[3] intercept   : AIC=inf, Time=28.14 sec
#  ARIMA(1,0,0)(1,1,1)[3] intercept   : AIC=inf, Time=22.31 sec
#  ARIMA(1,0,2)(1,1,1)[3] intercept   : AIC=inf, Time=60.07 sec
#  ARIMA(0,0,1)(1,1,1)[3]             : AIC=491465.044, Time=17.62 sec
#  ARIMA(0,0,1)(0,1,1)[3]             : AIC=491506.825, Time=8.26 sec
#  ARIMA(0,0,1)(1,1,0)[3]             : AIC=501200.699, Time=3.74 sec
#  ARIMA(0,0,1)(2,1,1)[3]             : AIC=inf, Time=16.25 sec
#  ARIMA(0,0,1)(1,1,2)[3]             : AIC=inf, Time=26.13 sec
#  ARIMA(0,0,1)(0,1,0)[3]             : AIC=512233.737, Time=2.57 sec
#  ARIMA(0,0,1)(0,1,2)[3]             : AIC=491471.781, Time=13.28 sec
#  ARIMA(0,0,1)(2,1,0)[3]             : AIC=498986.367, Time=5.51 sec
#  ARIMA(0,0,1)(2,1,2)[3]             : AIC=inf, Time=32.74 sec
#  ARIMA(0,0,0)(1,1,1)[3]             : AIC=493135.419, Time=5.19 sec
#  ARIMA(1,0,1)(1,1,1)[3]             : AIC=inf, Time=43.29 sec
#  ARIMA(0,0,2)(1,1,1)[3]             : AIC=491436.666, Time=24.44 sec
#  ARIMA(0,0,2)(0,1,1)[3]             : AIC=491492.718, Time=15.92 sec
#  ARIMA(0,0,2)(1,1,0)[3]             : AIC=501163.367, Time=5.14 sec
#  ARIMA(0,0,2)(2,1,1)[3]             : AIC=inf, Time=31.88 sec
#  ARIMA(0,0,2)(1,1,2)[3]             : AIC=inf, Time=30.79 sec
#  ARIMA(0,0,2)(0,1,0)[3]             : AIC=inf, Time=8.92 sec
#  ARIMA(0,0,2)(0,1,2)[3]             : AIC=491445.742, Time=33.12 sec
#  ARIMA(0,0,2)(2,1,0)[3]             : AIC=498892.692, Time=7.12 sec
#  ARIMA(0,0,2)(2,1,2)[3]             : AIC=inf, Time=42.85 sec
#  ARIMA(1,0,2)(1,1,1)[3]             : AIC=inf, Time=115.61 sec
#
# Best model:  ARIMA(0,0,2)(1,1,1)[3]
# Total fit time: 961.578 seconds
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                33494
# Model:             SARIMAX(0, 0, 2)x(1, 1, [1], 3)   Log Likelihood             -245713.333
# Date:                             Tue, 13 Apr 2021   AIC                         491436.666
# Time:                                     10:46:07   BIC                         491478.761
# Sample:                                          0   HQIC                        491450.103
#                                            - 33494
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          0.2313      0.004     59.031      0.000       0.224       0.239
# ma.L2          0.0306      0.004      7.908      0.000       0.023       0.038
# ar.S.L3        0.0449      0.004     10.984      0.000       0.037       0.053
# ma.S.L3       -0.9696      0.001   -917.156      0.000      -0.972      -0.967
# sigma2       1.38e+05    893.007    154.582      0.000    1.36e+05     1.4e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              3505.53
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.20   Skew:                             0.56
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.12
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
train=dataset['udsVenta'][:'2020-06-01']
test=dataset['udsVenta']['2020-06-02':]

# %%
test
# Out:
# Fecha
# 2020-06-07       0
# 2020-06-21       0
# 2020-06-28       0
# 2020-07-05       0
# 2020-07-21    1382
#               ...
# 2021-03-05       0
# 2021-03-06       0
# 2021-03-07       0
# 2021-03-08       0
# 2021-03-09       0
# Name: udsVenta, Length: 14354, dtype: int64

# %%
resDiff = sm.tsa.arma_order_select_ic(train, max_ar=7, max_ma=7, ic='aic', trend='c')
print('ARMA(p,q) =',resDiff['aic_min_order'],'is the best.')
# Out:
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# ARMA(p,q) = (7, 7) is the best.

# %%
model_sarima = sm.tsa.statespace.SARIMAX(train, trend='n', order=(7,1,0)).fit()
print(model_sarima.summary())
# Out:
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:585: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it is not'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-0eeaeef9df05> in <module>
# ----> 1 sarima_mod6 = sm.tsa.statespace.SARIMAX(dataset, trend='n', order=(7,1,0)).fit()
#       2 print(sarima_mod6.summary())
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py in __init__(self, endog, exog, order, seasonal_order, trend, measurement_error, time_varying_regression, mle_regression, simple_differencing, enforce_stationarity, enforce_invertibility, hamilton_representation, concentrate_scale, trend_offset, use_exact_diffuse, dates, freq, missing, validate_specification, **kwargs)
#     326                  **kwargs):
#     327
# --> 328         self._spec = SARIMAXSpecification(
#     329             endog, exog=exog, order=order, seasonal_order=seasonal_order,
#     330             trend=trend, enforce_stationarity=None, enforce_invertibility=None,
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\arima\specification.py in __init__(self, endog, exog, order, seasonal_order, ar_order, diff, ma_order, seasonal_ar_order, seasonal_diff, seasonal_ma_order, seasonal_periods, trend, enforce_stationarity, enforce_invertibility, concentrate_scale, trend_offset, dates, freq, missing, validate_specification)
#     452         if (validate_specification and not faux_endog and
#     453                 self.endog.ndim > 1 and self.endog.shape[1] > 1):
# --> 454             raise ValueError('SARIMAX models require univariate `endog`. Got'
#     455                              ' shape %s.' % str(self.endog.shape))
#     456
#
# ValueError: SARIMAX models require univariate `endog`. Got shape (33494, 10).

# %%
import statsmodels.api as sm

fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(train, lags=40, ax=ax1) # 
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(train, lags=40, ax=ax2)# , lags=40

# %%
model_sarima = sm.tsa.statespace.SARIMAX(train, order=(1,1,1), seasonal_order=(1,0,0,7),enforce_stationarity=False,enforce_invertibility=False)
model_fit=model_sarima.fit(disp=False)
# Out:
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:585: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it is not'
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:585: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it is not'

# %%
K=len(test)
forecast=model_fit.forecast(K)
forecast=np.exp(forecast)

series=dataset['udsVenta']
split_point=round(len(series)*0.5)

plt.figure(figsize=(10,5))
plt.plot(forecast,'r')
plt.plot(series,'b')
plt.title('RMSE: %.2f'% np.sqrt(sum((forecast-test)**2)/len(test)))
plt.xlabel("Fecha")
plt.ylabel("udsVenta")
plt.autoscale(enable=True,axis='x',tight=True)
plt.axvline(x=series.index[split_point],color='black')
# Out:
# C:\Users\subir\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:376: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   warnings.warn('No supported index is available.'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-e86b615a5d6e> in <module>
#       9 plt.plot(forecast,'r')
#      10 plt.plot(series,'b')
# ---> 11 plt.title('RMSE: %.2f'% np.sqrt(sum((forecast-test)**2)/len(test)))
#      12 plt.xlabel("Fecha")
#      13 plt.ylabel("udsVenta")
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(left, right)
#     336     def wrapper(left, right):
#     337
# --> 338         left, right = _align_method_SERIES(left, right)
#     339         res_name = get_op_result_name(left, right)
#     340
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in _align_method_SERIES(left, right, align_asobject)
#     320                 right = right.astype(object)
#     321
# --> 322             left, right = left.align(right, copy=False)
#     323
#     324     return left, right
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#    4272         broadcast_axis=None,
#    4273     ):
# -> 4274         return super().align(
#    4275             other,
#    4276             join=join,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#    8557             )
#    8558         elif isinstance(other, ABCSeries):
# -> 8559             return self._align_series(
#    8560                 other,
#    8561                 join=join,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _align_series(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis)
#    8660                 join_index, lidx, ridx = None, None, None
#    8661             else:
# -> 8662                 join_index, lidx, ridx = self.index.join(
#    8663                     other.index, how=join, level=level, return_indexers=True
#    8664                 )
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in join(self, other, how, level, return_indexers, sort)
#     628         if how == "outer" and self is not other:
#     629             # note: could return RangeIndex in more circumstances
# --> 630             return self._int64index.join(other, how, level, return_indexers, sort)
#     631
#     632         return super().join(other, how, level, return_indexers, sort)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in join(self, other, how, level, return_indexers, sort)
#    3470         if self._join_precedence < other._join_precedence:
#    3471             how = {"right": "left", "left": "right"}.get(how, how)
# -> 3472             result = other.join(
#    3473                 self, how=how, level=level, return_indexers=return_indexers
#    3474             )
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\datetimelike.py in join(self, other, how, level, return_indexers, sort)
#     884
#     885         this, other = self._maybe_utc_convert(other)
# --> 886         return Index.join(
#     887             this,
#     888             other,
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in join(self, other, how, level, return_indexers, sort)
#    3481             this = self.astype("O")
#    3482             other = other.astype("O")
# -> 3483             return this.join(other, how=how, return_indexers=return_indexers)
#    3484
#    3485         _validate_join_method(how)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in join(self, other, how, level, return_indexers, sort)
#    3495                 )
#    3496             else:
# -> 3497                 return self._join_non_unique(
#    3498                     other, how=how, return_indexers=return_indexers
#    3499                 )
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _join_non_unique(self, other, how, return_indexers)
#    3622         rvalues = other._get_engine_target()
#    3623
# -> 3624         left_idx, right_idx = _get_join_indexers(
#    3625             [lvalues], [rvalues], how=how, sort=True
#    3626         )
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_join_indexers(left_keys, right_keys, sort, how, **kwargs)
#    1326         for n in range(len(left_keys))
#    1327     )
# -> 1328     zipped = zip(*mapped)
#    1329     llab, rlab, shape = [list(x) for x in zipped]
#    1330
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in <genexpr>(.0)
#    1323     # get left & right join labels and num. of levels at each location
#    1324     mapped = (
# -> 1325         _factorize_keys(left_keys[n], right_keys[n], sort=sort, how=how)
#    1326         for n in range(len(left_keys))
#    1327     )
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _factorize_keys(lk, rk, sort, how)
#    1978     if sort:
#    1979         uniques = rizer.uniques.to_array()
# -> 1980         llab, rlab = _sort_labels(uniques, llab, rlab)
#    1981
#    1982     # NA group
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _sort_labels(uniques, left, right)
#    2003     labels = np.concatenate([left, right])
#    2004
# -> 2005     _, new_labels = algos.safe_sort(uniques, labels, na_sentinel=-1)
#    2006     new_labels = ensure_int64(new_labels)
#    2007     new_left, new_right = new_labels[:llength], new_labels[llength:]
#
# ~\anaconda3\lib\site-packages\pandas\core\algorithms.py in safe_sort(values, codes, na_sentinel, assume_unique, verify)
#    2061     ):
#    2062         # unorderable in py3 if mixed str/int
# -> 2063         ordered = sort_mixed(values)
#    2064     else:
#    2065         try:
#
# ~\anaconda3\lib\site-packages\pandas\core\algorithms.py in sort_mixed(values)
#    2051         # order ints before strings, safe in py3
#    2052         str_pos = np.array([isinstance(x, str) for x in values], dtype=bool)
# -> 2053         nums = np.sort(values[~str_pos])
#    2054         strs = np.sort(values[str_pos])
#    2055         return np.concatenate([nums, np.asarray(strs, dtype=object)])
#
# <__array_function__ internals> in sort(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in sort(a, axis, kind, order)
#     989     else:
#     990         a = asanyarray(a).copy(order="K")
# --> 991     a.sort(axis=axis, kind=kind, order=order)
#     992     return a
#     993
#
# TypeError: '<' not supported between instances of 'int' and 'Timestamp'

# %%
train.head()
# Out:
# Fecha
# 2019-06-11    1037
# 2019-06-16       0
# 2019-06-19    1382
# 2019-07-21       0
# 2019-07-28       0
# Name: udsVenta, dtype: int64

# %%
dataset
# Out:
#             Producto  udsVenta  udsStock  flag   Precio  Festivo  \
# Fecha
# 2019-06-11         1      1037      1627     0  4.19310        0
# 2019-06-16         1         0       227     0  4.19310        0
# 2019-06-19         1      1382      1433     0  4.19310        0
# 2019-07-21         1         0      1141     0  4.19310        0
# 2019-07-28         1         0       961     0  4.19310        0
# ...              ...       ...       ...   ...      ...      ...
# 2021-03-05        99         0       346     0  4.35323        0
# 2021-03-06        99         0       346     0  4.35323        0
# 2021-03-07        99         0       346     0  4.35323        0
# 2021-03-08        99         0       346     0  4.35323        0
# 2021-03-09        99         0       540     0  4.35323        0
#
#             Fin de semana   Año  Mes  Weekday
# Fecha
# 2019-06-11              0  2019    6        1
# 2019-06-16              1  2019    6        6
# 2019-06-19              0  2019    6        2
# 2019-07-21              1  2019    7        6
# 2019-07-28              1  2019    7        6
# ...                   ...   ...  ...      ...
# 2021-03-05              0  2021    3        4
# 2021-03-06              1  2021    3        5
# 2021-03-07              1  2021    3        6
# 2021-03-08              0  2021    3        0
# 2021-03-09              0  2021    3        1
#
# [33494 rows x 10 columns]

# %%
dataset=dataset.drop(columns='Fecha_2')

# %%
dataset_xgboost=dataset
dataset_xgboost
# Out:
#            Fecha  Producto  udsVenta  udsStock  flag   Precio  Festivo  \
# 6     2019-06-11         1      1037      1627     0  4.19310        0
# 11    2019-06-16         1         0       227     0  4.19310        0
# 14    2019-06-19         1      1382      1433     0  4.19310        0
# 46    2019-07-21         1         0      1141     0  4.19310        0
# 53    2019-07-28         1         0       961     0  4.19310        0
# ...          ...       ...       ...       ...   ...      ...      ...
# 41300 2021-03-05        99         0       346     0  4.35323        0
# 41301 2021-03-06        99         0       346     0  4.35323        0
# 41302 2021-03-07        99         0       346     0  4.35323        0
# 41303 2021-03-08        99         0       346     0  4.35323        0
# 41304 2021-03-09        99         0       540     0  4.35323        0
#
#        Fin de semana   Año  Mes  Weekday
# 6                  0  2019    6        1
# 11                 1  2019    6        6
# 14                 0  2019    6        2
# 46                 1  2019    7        6
# 53                 1  2019    7        6
# ...              ...   ...  ...      ...
# 41300              0  2021    3        4
# 41301              1  2021    3        5
# 41302              1  2021    3        6
# 41303              0  2021    3        0
# 41304              0  2021    3        1
#
# [33494 rows x 11 columns]

# %%
dataset_xgboost=dataset_xgboost.set_index(dataset_xgboost['Fecha'])
dataset_xgboost=dataset_xgboost.sort_index()

# %%
train_xgboost=dataset_xgboost['2019-07-01':'2020-06-01']
test_xgboost=dataset_xgboost['2020-06-02':]

print('Train Dataset:',train_xgboost.shape)
print('Test Dataset:',test_xgboost.shape)
# Out:
# Train Dataset: (17767, 11)
# Test Dataset: (14354, 11)

# %%
train_xgboost.corr()
# Out:
#                Producto  udsVenta  udsStock      flag    Precio   Festivo  \
# Producto       1.000000 -0.362436 -0.573537 -0.067116  0.115049 -0.013103
# udsVenta      -0.362436  1.000000  0.321709  0.145292 -0.109008 -0.128107
# udsStock      -0.573537  0.321709  1.000000  0.186299 -0.213349  0.013770
# flag          -0.067116  0.145292  0.186299  1.000000 -0.671949 -0.000272
# Precio         0.115049 -0.109008 -0.213349 -0.671949  1.000000 -0.003654
# Festivo       -0.013103 -0.128107  0.013770 -0.000272 -0.003654  1.000000
# Fin de semana -0.040230 -0.417026  0.014375 -0.009547 -0.003024 -0.050093
# Año            0.015183  0.008042  0.005699 -0.011907 -0.015357  0.016754
# Mes           -0.009040 -0.009280 -0.002512 -0.001956  0.017786  0.024548
# Weekday       -0.014477 -0.333502  0.025535 -0.012529  0.004950  0.032353
#
#                Fin de semana       Año       Mes   Weekday
# Producto           -0.040230  0.015183 -0.009040 -0.014477
# udsVenta           -0.417026  0.008042 -0.009280 -0.333502
# udsStock            0.014375  0.005699 -0.002512  0.025535
# flag               -0.009547 -0.011907 -0.001956 -0.012529
# Precio             -0.003024 -0.015357  0.017786  0.004950
# Festivo            -0.050093  0.016754  0.024548  0.032353
# Fin de semana       1.000000  0.006576  0.000927  0.801764
# Año                 0.006576  1.000000 -0.896040  0.011040
# Mes                 0.000927 -0.896040  1.000000 -0.005017
# Weekday             0.801764  0.011040 -0.005017  1.000000

# %%
train_xgboost
# Out:
#                 Fecha  Producto  udsVenta  udsStock  flag   Precio  Festivo  \
# Fecha
# 2019-07-01 2019-07-01        98       238       192     0  3.53160        0
# 2019-07-01 2019-07-01        58        16        33     0  4.35323        0
# 2019-07-01 2019-07-01        35       605       310     0  4.77000        0
# 2019-07-01 2019-07-01        69       432        22     1  4.35323        0
# 2019-07-01 2019-07-01        24      1721       801     0  4.77000        0
# ...               ...       ...       ...       ...   ...      ...      ...
# 2020-06-01 2020-06-01        80         0       339     0  4.35323        0
# 2020-06-01 2020-06-01        66       245       328     0  5.03100        0
# 2020-06-01 2020-06-01        67       579       449     0  4.63500        0
# 2020-06-01 2020-06-01        78       261        40     0  4.18500        0
# 2020-06-01 2020-06-01        50       612      1434     1  2.85390        0
#
#             Fin de semana   Año  Mes  Weekday
# Fecha
# 2019-07-01              0  2019    7        0
# 2019-07-01              0  2019    7        0
# 2019-07-01              0  2019    7        0
# 2019-07-01              0  2019    7        0
# 2019-07-01              0  2019    7        0
# ...                   ...   ...  ...      ...
# 2020-06-01              0  2020    6        0
# 2020-06-01              0  2020    6        0
# 2020-06-01              0  2020    6        0
# 2020-06-01              0  2020    6        0
# 2020-06-01              0  2020    6        0
#
# [17767 rows x 11 columns]

# %%
X_train_xgboost=train_xgboost[['']]
